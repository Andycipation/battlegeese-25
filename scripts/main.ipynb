# %%
import matplotlib.pyplot as plt

# %%
s = '''
DefaultSmall: 20, 20
Filter: 21, 21
Justice: 21, 20
Racetrack: 25, 25
catface: 30, 30
windmill: 30, 30
Barcode: 50, 21
Bread: 35, 29
DefaultMedium: 35, 35
Fossil: 30, 30
Money: 35, 35
SaltyPepper: 40, 40
TargetPractice: 30, 30
UnderTheSea: 45, 45
fix: 40, 50
gridworld: 31, 31
leavemealone: 50, 30
quack: 30, 35
BunnyGame: 30, 50
DefaultLarge: 50, 30
Flower: 45, 41
Mirage: 40, 40
MoneyTower: 35, 50
Snowglobe: 40, 40
Thirds: 55, 40
UglySweater: 50, 50
galaxy: 45, 45
memstore: 59, 39
sayhi: 40, 50
sierpinski: 39, 50
DefaultHuge: 59, 59
Gears: 55, 55
Piglets2: 60, 40
Restart: 55, 55
SMILE: 60, 60
gardenworld: 60, 60
giver: 50, 50
Barcode: 50, 21
Bread: 35, 29
DefaultSmall: 20, 20
Fossil: 30, 30
Gears: 55, 55
SMILE: 60, 60
SaltyPepper: 40, 40
TargetPractice: 30, 30
Thirds: 55, 40
gardenworld: 60, 60
giver: 50, 50
leavemealone: 50, 30
memstore: 59, 39
quack: 30, 35
Gears: 55, 55
MoneyTower: 35, 50
BunnyGame: 30, 50
Mirage: 40, 40
Piglets2: 60, 40
Restart: 55, 55
Flower: 45, 41
Gears: 55, 55
Justice: 21, 20
Mirage: 40, 40
MoneyTower: 35, 50
Piglets2: 60, 40
SMILE: 60, 60
Restart: 55, 55
SaltyPepper: 40, 40
Snowglobe: 40, 40
galaxy: 45, 45
gardenworld: 60, 60
giver: 50, 50
gridworld: 31, 31
memstore: 59, 39
quack: 30, 35
sayhi: 40, 50
sierpinski: 39, 50
'''
sizes = []
for line in s.strip().splitlines():
    name, width, height = line.split()
    name = name.removesuffix(':')
    width = int(width.removesuffix(','))
    height = int(height)
    size = width * height
    sizes.append(size)
sizes.sort()
sizes
# Out:
# [400,
#  400,
#  420,
#  420,
#  441,
#  625,
#  900,
#  900,
#  900,
#  900,
#  900,
#  900,
#  961,
#  961,
#  1015,
#  1015,
#  1050,
#  1050,
#  1050,
#  1050,
#  1050,
#  1225,
#  1225,
#  1500,
#  1500,
#  1500,
#  1500,
#  1500,
#  1600,
#  1600,
#  1600,
#  1600,
#  1600,
#  1600,
#  1600,
#  1600,
#  1750,
#  1750,
#  1750,
#  1845,
#  1845,
#  1950,
#  1950,
#  2000,
#  2000,
#  2000,
#  2025,
#  2025,
#  2025,
#  2200,
#  2200,
#  2301,
#  2301,
#  2301,
#  2400,
#  2400,
#  2400,
#  2500,
#  2500,
#  2500,
#  2500,
#  3025,
#  3025,
#  3025,
#  3025,
#  3025,
#  3025,
#  3025,
#  3481,
#  3600,
#  3600,
#  3600,
#  3600,
#  3600,
#  3600]

# %%
plt.title('map sizes histogram')
plt.hist(sizes, bins=50)
plt.axvline(x=700, c='r')
plt.axvline(x=1800, c='r')
plt.show()
